# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#p4d.24xlarge" data-toc-modified-id="p4d.24xlarge-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>p4d.24xlarge</a></span><ul class="toc-item"><li><span><a href="#Mortgage" data-toc-modified-id="Mortgage-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Mortgage</a></span></li><li><span><a href="#HiBench-600M" data-toc-modified-id="HiBench-600M-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>HiBench-600M</a></span></li></ul></li><li><span><a href="#c5.metal" data-toc-modified-id="c5.metal-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>c5.metal</a></span><ul class="toc-item"><li><span><a href="#Mortgage" data-toc-modified-id="Mortgage-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Mortgage</a></span></li><li><span><a href="#HiBench-600M" data-toc-modified-id="HiBench-600M-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>HiBench-600M</a></span></li></ul></li></ul></div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
pd.options.display.max_rows = 10
pd.options.display.float_format = '{:,.2f}'.format
plt.rcParams['figure.figsize'] = (16, 12)

# %% [markdown]
# ## p4d.24xlarge

# %% [markdown]
# ### Mortgage

# %%
profile = '/home/yuzhou/aws_test/p4d/profile/app-20210217054721-0014/ip-172-31-29-158'

# %%
fig, axes = plt.subplots(nrows=2, ncols=4)

df = pd.read_csv(profile + '/gpu.txt', header=0, names=['timestamp', 'index', '%util', '%mem', 'mbmem'], parse_dates=True)
df['%util'] = df['%util'].str.extract(r'(\w+)\s+%')

gpu0_util = df.loc[df['index'] == 0]['%util'].astype(float)
gpu1_util = df.loc[df['index'] == 1]['%util'].astype(float)
gpu2_util = df.loc[df['index'] == 2]['%util'].astype(float)
gpu3_util = df.loc[df['index'] == 3]['%util'].astype(float)
gpu4_util = df.loc[df['index'] == 4]['%util'].astype(float)
gpu5_util = df.loc[df['index'] == 5]['%util'].astype(float)
gpu6_util = df.loc[df['index'] == 6]['%util'].astype(float)
gpu7_util = df.loc[df['index'] == 7]['%util'].astype(float)

gpu0_util.plot(ax=axes[0,0]); axes[0,0].set_title("gpu0 %util")
gpu1_util.plot(ax=axes[0,1]); axes[0,1].set_title("gpu1 %util")
gpu2_util.plot(ax=axes[0,2]); axes[0,2].set_title("gpu2 %util")
gpu3_util.plot(ax=axes[0,3]); axes[0,3].set_title("gpu3 %util")
gpu4_util.plot(ax=axes[1,0]); axes[1,0].set_title("gpu4 %util")
gpu5_util.plot(ax=axes[1,1]); axes[1,1].set_title("gpu5 %util")
gpu6_util.plot(ax=axes[1,2]); axes[1,2].set_title("gpu6 %util")
gpu7_util.plot(ax=axes[1,3]); axes[1,3].set_title("gpu7 %util")
# Out:
# Text(0.5, 1.0, 'gpu7 %util')

# %%
cpu_df0 = pd.read_csv(profile + '/sar_cpu.sar', skiprows=2, sep='\s+')
mem_df0 = pd.read_csv(profile + '/sar_mem.sar', skiprows=2, sep='\s+')
disk_df0 = pd.read_csv(profile + '/sar_disk.sar', skiprows=2, sep='\s+')
nic_df0 = pd.read_csv(profile + '/sar_nic.sar', skiprows=2, sep='\s+', index_col='IFACE')
nic_df0 = nic_df0.loc['ens32']

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
cpu_df0['%user'].plot(ax=axes[0,0]); axes[0,0].set_title('%cpu')
mem_df0['%memused'].plot(ax=axes[0,1]); axes[0,1].set_title('%mem')
disk_df0[['rkB/s', 'wkB/s']].plot(ax=axes[1,0]); axes[1,0].set_title('disk')
nic_df0[['rxkB/s', 'txkB/s']].plot(ax=axes[1,1]); axes[1,1].set_title('nic')
# Out:
# Text(0.5, 1.0, 'nic')

# %% [markdown]
# ### HiBench-600M

# %%
profile = '/home/yuzhou/aws_test/p4d/profile/app-20210217060929-0019/ip-172-31-29-158'

# %%
fig, axes = plt.subplots(nrows=2, ncols=4)

df = pd.read_csv(profile + '/gpu.txt', header=0, names=['timestamp', 'index', '%util', '%mem', 'mbmem'], parse_dates=True)
df['%util'] = df['%util'].str.extract(r'(\w+)\s+%')

gpu0_util = df.loc[df['index'] == 0]['%util'].astype(float)
gpu1_util = df.loc[df['index'] == 1]['%util'].astype(float)
gpu2_util = df.loc[df['index'] == 2]['%util'].astype(float)
gpu3_util = df.loc[df['index'] == 3]['%util'].astype(float)
gpu4_util = df.loc[df['index'] == 4]['%util'].astype(float)
gpu5_util = df.loc[df['index'] == 5]['%util'].astype(float)
gpu6_util = df.loc[df['index'] == 6]['%util'].astype(float)
gpu7_util = df.loc[df['index'] == 7]['%util'].astype(float)

gpu0_util.plot(ax=axes[0,0]); axes[0,0].set_title("gpu0 %util")
gpu1_util.plot(ax=axes[0,1]); axes[0,1].set_title("gpu1 %util")
gpu2_util.plot(ax=axes[0,2]); axes[0,2].set_title("gpu2 %util")
gpu3_util.plot(ax=axes[0,3]); axes[0,3].set_title("gpu3 %util")
gpu4_util.plot(ax=axes[1,0]); axes[1,0].set_title("gpu4 %util")
gpu5_util.plot(ax=axes[1,1]); axes[1,1].set_title("gpu5 %util")
gpu6_util.plot(ax=axes[1,2]); axes[1,2].set_title("gpu6 %util")
gpu7_util.plot(ax=axes[1,3]); axes[1,3].set_title("gpu7 %util")
# Out:
# Text(0.5, 1.0, 'gpu7 %util')

# %%
cpu_df0 = pd.read_csv(profile + '/sar_cpu.sar', skiprows=2, sep='\s+')
mem_df0 = pd.read_csv(profile + '/sar_mem.sar', skiprows=2, sep='\s+')
disk_df0 = pd.read_csv(profile + '/sar_disk.sar', skiprows=2, sep='\s+')
nic_df0 = pd.read_csv(profile + '/sar_nic.sar', skiprows=2, sep='\s+', index_col='IFACE')
nic_df0 = nic_df0.loc['ens32']

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)
cpu_df0['%user'].plot(ax=axes[0,0]); axes[0,0].set_title('%cpu')
mem_df0['%memused'].plot(ax=axes[0,1]); axes[0,1].set_title('%mem')
disk_df0[['rkB/s', 'wkB/s']].plot(ax=axes[1,0]); axes[1,0].set_title('disk')
nic_df0[['rxkB/s', 'txkB/s']].plot(ax=axes[1,1]); axes[1,1].set_title('nic')
# Out:
# Text(0.5, 1.0, 'nic')

# %% [markdown]
# ## c5.metal

# %% [markdown]
# ### Mortgage

# %%
profile = '/home/yuzhou/aws_test/c5xmetal/home/sparkuser/profile/application_1614062157897_0007'
nodes = ['172.31.48.87',  '172.31.50.230',  '172.31.52.207',  '172.31.56.136',  '172.31.57.117',  '172.31.59.90',  '172.31.62.187',  '172.31.63.214']

# %%
cpu_df0 = pd.read_csv(profile + '/' + nodes[0] + '/sar_cpu.sar', skiprows=2, sep='\s+')
cpu_df1 = pd.read_csv(profile + '/' + nodes[1] + '/sar_cpu.sar', skiprows=2, sep='\s+')
cpu_df2 = pd.read_csv(profile + '/' + nodes[2] + '/sar_cpu.sar', skiprows=2, sep='\s+')
cpu_df3 = pd.read_csv(profile + '/' + nodes[3] + '/sar_cpu.sar', skiprows=2, sep='\s+')
cpu_df4 = pd.read_csv(profile + '/' + nodes[4] + '/sar_cpu.sar', skiprows=2, sep='\s+')
cpu_df5 = pd.read_csv(profile + '/' + nodes[5] + '/sar_cpu.sar', skiprows=2, sep='\s+')
cpu_df6 = pd.read_csv(profile + '/' + nodes[6] + '/sar_cpu.sar', skiprows=2, sep='\s+')
cpu_df7 = pd.read_csv(profile + '/' + nodes[7] + '/sar_cpu.sar', skiprows=2, sep='\s+')

# %%
fig, axes = plt.subplots(nrows=2, ncols=4)
cpu_df0['%user'].plot(ax=axes[0,0]); axes[0,0].set_title('node0')
cpu_df1['%user'].plot(ax=axes[0,1]); axes[0,1].set_title('node1')
cpu_df2['%user'].plot(ax=axes[0,2]); axes[0,2].set_title('node2')
cpu_df3['%user'].plot(ax=axes[0,3]); axes[0,3].set_title('node3')
cpu_df4['%user'].plot(ax=axes[1,0]); axes[1,0].set_title('node4')
cpu_df5['%user'].plot(ax=axes[1,1]); axes[1,1].set_title('node5')
cpu_df6['%user'].plot(ax=axes[1,2]); axes[1,2].set_title('node6')
cpu_df7['%user'].plot(ax=axes[1,3]); axes[1,3].set_title('node7')
# Out:
# Text(0.5, 1.0, 'node7')

# %%
disk_df0 = pd.read_csv(profile + '/' + nodes[0] + '/sar_disk.sar', skiprows=2, sep='\s+')
disk_df1 = pd.read_csv(profile + '/' + nodes[1] + '/sar_disk.sar', skiprows=2, sep='\s+')
disk_df2 = pd.read_csv(profile + '/' + nodes[2] + '/sar_disk.sar', skiprows=2, sep='\s+')
disk_df3 = pd.read_csv(profile + '/' + nodes[3] + '/sar_disk.sar', skiprows=2, sep='\s+')
disk_df4 = pd.read_csv(profile + '/' + nodes[4] + '/sar_disk.sar', skiprows=2, sep='\s+')
disk_df5 = pd.read_csv(profile + '/' + nodes[5] + '/sar_disk.sar', skiprows=2, sep='\s+')
disk_df6 = pd.read_csv(profile + '/' + nodes[6] + '/sar_disk.sar', skiprows=2, sep='\s+')
disk_df7 = pd.read_csv(profile + '/' + nodes[7] + '/sar_disk.sar', skiprows=2, sep='\s+')

# %%
fig, axes = plt.subplots(nrows=2, ncols=4)
disk_df0[['rkB/s', 'wkB/s']].plot(ax=axes[0,0]); axes[0,0].set_title('node0')
disk_df1[['rkB/s', 'wkB/s']].plot(ax=axes[0,1]); axes[0,1].set_title('node1')
disk_df2[['rkB/s', 'wkB/s']].plot(ax=axes[0,2]); axes[0,2].set_title('node2')
disk_df3[['rkB/s', 'wkB/s']].plot(ax=axes[0,3]); axes[0,3].set_title('node3')
disk_df4[['rkB/s', 'wkB/s']].plot(ax=axes[1,0]); axes[1,0].set_title('node4')
disk_df5[['rkB/s', 'wkB/s']].plot(ax=axes[1,1]); axes[1,1].set_title('node5')
disk_df6[['rkB/s', 'wkB/s']].plot(ax=axes[1,2]); axes[1,2].set_title('node6')
disk_df7[['rkB/s', 'wkB/s']].plot(ax=axes[1,3]); axes[1,3].set_title('node7')
# Out:
# Text(0.5, 1.0, 'node7')

# %%
mem_df0 = pd.read_csv(profile + '/' + nodes[0] + '/sar_mem.sar', skiprows=2, sep='\s+')
mem_df1 = pd.read_csv(profile + '/' + nodes[1] + '/sar_mem.sar', skiprows=2, sep='\s+')
mem_df2 = pd.read_csv(profile + '/' + nodes[2] + '/sar_mem.sar', skiprows=2, sep='\s+')
mem_df3 = pd.read_csv(profile + '/' + nodes[3] + '/sar_mem.sar', skiprows=2, sep='\s+')
mem_df4 = pd.read_csv(profile + '/' + nodes[4] + '/sar_mem.sar', skiprows=2, sep='\s+')
mem_df5 = pd.read_csv(profile + '/' + nodes[5] + '/sar_mem.sar', skiprows=2, sep='\s+')
mem_df6 = pd.read_csv(profile + '/' + nodes[6] + '/sar_mem.sar', skiprows=2, sep='\s+')
mem_df7 = pd.read_csv(profile + '/' + nodes[7] + '/sar_mem.sar', skiprows=2, sep='\s+')

# %%
fig, axes = plt.subplots(nrows=2, ncols=4)
mem_df0['%memused'].plot(ax=axes[0,0]); axes[0,0].set_title('node0')
mem_df1['%memused'].plot(ax=axes[0,1]); axes[0,1].set_title('node1')
mem_df2['%memused'].plot(ax=axes[0,2]); axes[0,2].set_title('node2')
mem_df3['%memused'].plot(ax=axes[0,3]); axes[0,3].set_title('node3')
mem_df4['%memused'].plot(ax=axes[1,0]); axes[1,0].set_title('node4')
mem_df5['%memused'].plot(ax=axes[1,1]); axes[1,1].set_title('node5')
mem_df6['%memused'].plot(ax=axes[1,2]); axes[1,2].set_title('node6')
mem_df7['%memused'].plot(ax=axes[1,3]); axes[1,3].set_title('node7')
# Out:
# Text(0.5, 1.0, 'node7')

# %%
nic_df0 = pd.read_csv(profile + '/' + nodes[0] + '/sar_nic.sar', skiprows=2, sep='\s+', index_col='IFACE')
nic_df0 = nic_df0.loc['enp125s0']
nic_df1 = pd.read_csv(profile + '/' + nodes[1] + '/sar_nic.sar', skiprows=2, sep='\s+', index_col='IFACE')
nic_df1 = nic_df1.loc['enp125s0']
nic_df2 = pd.read_csv(profile + '/' + nodes[2] + '/sar_nic.sar', skiprows=2, sep='\s+', index_col='IFACE')
nic_df2 = nic_df2.loc['enp125s0']
nic_df3 = pd.read_csv(profile + '/' + nodes[3] + '/sar_nic.sar', skiprows=2, sep='\s+', index_col='IFACE')
nic_df3 = nic_df3.loc['enp125s0']
nic_df4 = pd.read_csv(profile + '/' + nodes[4] + '/sar_nic.sar', skiprows=2, sep='\s+', index_col='IFACE')
nic_df4 = nic_df4.loc['enp125s0']
nic_df5 = pd.read_csv(profile + '/' + nodes[5] + '/sar_nic.sar', skiprows=2, sep='\s+', index_col='IFACE')
nic_df5 = nic_df5.loc['enp125s0']
nic_df6 = pd.read_csv(profile + '/' + nodes[6] + '/sar_nic.sar', skiprows=2, sep='\s+', index_col='IFACE')
nic_df6 = nic_df6.loc['enp125s0']
nic_df7 = pd.read_csv(profile + '/' + nodes[7] + '/sar_nic.sar', skiprows=2, sep='\s+', index_col='IFACE')
nic_df7 = nic_df7.loc['enp125s0']

# %%
fig, axes = plt.subplots(nrows=2, ncols=4)
nic_df0[['rxkB/s', 'txkB/s']].plot(ax=axes[0,0]); axes[0,0].set_title('node0')
nic_df1[['rxkB/s', 'txkB/s']].plot(ax=axes[0,1]); axes[0,1].set_title('node1')
nic_df2[['rxkB/s', 'txkB/s']].plot(ax=axes[0,2]); axes[0,2].set_title('node2')
nic_df3[['rxkB/s', 'txkB/s']].plot(ax=axes[0,3]); axes[0,3].set_title('node3')
nic_df4[['rxkB/s', 'txkB/s']].plot(ax=axes[1,0]); axes[1,0].set_title('node4')
nic_df5[['rxkB/s', 'txkB/s']].plot(ax=axes[1,1]); axes[1,1].set_title('node5')
nic_df6[['rxkB/s', 'txkB/s']].plot(ax=axes[1,2]); axes[1,2].set_title('node6')
nic_df7[['rxkB/s', 'txkB/s']].plot(ax=axes[1,3]); axes[1,3].set_title('node7')
# Out:
# Text(0.5, 1.0, 'node7')

# %% [markdown]
# ### HiBench-600M

# %%
profile = '/home/yuzhou/aws_test/c5xmetal/home/sparkuser/profile/application_1614045517521_0003'
nodes = ['172.31.48.87',  '172.31.50.230',  '172.31.52.207',  '172.31.56.136',  '172.31.57.117',  '172.31.59.90',  '172.31.62.187',  '172.31.63.214']

# %%
cpu_df0 = pd.read_csv(profile + '/' + nodes[0] + '/sar_cpu.sar', skiprows=2, sep='\s+')
cpu_df1 = pd.read_csv(profile + '/' + nodes[1] + '/sar_cpu.sar', skiprows=2, sep='\s+')
cpu_df2 = pd.read_csv(profile + '/' + nodes[2] + '/sar_cpu.sar', skiprows=2, sep='\s+')
cpu_df3 = pd.read_csv(profile + '/' + nodes[3] + '/sar_cpu.sar', skiprows=2, sep='\s+')
cpu_df4 = pd.read_csv(profile + '/' + nodes[4] + '/sar_cpu.sar', skiprows=2, sep='\s+')
cpu_df5 = pd.read_csv(profile + '/' + nodes[5] + '/sar_cpu.sar', skiprows=2, sep='\s+')
cpu_df6 = pd.read_csv(profile + '/' + nodes[6] + '/sar_cpu.sar', skiprows=2, sep='\s+')
cpu_df7 = pd.read_csv(profile + '/' + nodes[7] + '/sar_cpu.sar', skiprows=2, sep='\s+')

# %%
fig, axes = plt.subplots(nrows=2, ncols=4)
cpu_df0['%user'].plot(ax=axes[0,0]); axes[0,0].set_title('node0')
cpu_df1['%user'].plot(ax=axes[0,1]); axes[0,1].set_title('node1')
cpu_df2['%user'].plot(ax=axes[0,2]); axes[0,2].set_title('node2')
cpu_df3['%user'].plot(ax=axes[0,3]); axes[0,3].set_title('node3')
cpu_df4['%user'].plot(ax=axes[1,0]); axes[1,0].set_title('node4')
cpu_df5['%user'].plot(ax=axes[1,1]); axes[1,1].set_title('node5')
cpu_df6['%user'].plot(ax=axes[1,2]); axes[1,2].set_title('node6')
cpu_df7['%user'].plot(ax=axes[1,3]); axes[1,3].set_title('node7')
# Out:
# Text(0.5, 1.0, 'node7')

# %%
disk_df0 = pd.read_csv(profile + '/' + nodes[0] + '/sar_disk.sar', skiprows=2, sep='\s+')
disk_df1 = pd.read_csv(profile + '/' + nodes[1] + '/sar_disk.sar', skiprows=2, sep='\s+')
disk_df2 = pd.read_csv(profile + '/' + nodes[2] + '/sar_disk.sar', skiprows=2, sep='\s+')
disk_df3 = pd.read_csv(profile + '/' + nodes[3] + '/sar_disk.sar', skiprows=2, sep='\s+')
disk_df4 = pd.read_csv(profile + '/' + nodes[4] + '/sar_disk.sar', skiprows=2, sep='\s+')
disk_df5 = pd.read_csv(profile + '/' + nodes[5] + '/sar_disk.sar', skiprows=2, sep='\s+')
disk_df6 = pd.read_csv(profile + '/' + nodes[6] + '/sar_disk.sar', skiprows=2, sep='\s+')
disk_df7 = pd.read_csv(profile + '/' + nodes[7] + '/sar_disk.sar', skiprows=2, sep='\s+')

# %%
fig, axes = plt.subplots(nrows=2, ncols=4)
disk_df0[['rkB/s', 'wkB/s']].plot(ax=axes[0,0]); axes[0,0].set_title('node0')
disk_df1[['rkB/s', 'wkB/s']].plot(ax=axes[0,1]); axes[0,1].set_title('node1')
disk_df2[['rkB/s', 'wkB/s']].plot(ax=axes[0,2]); axes[0,2].set_title('node2')
disk_df3[['rkB/s', 'wkB/s']].plot(ax=axes[0,3]); axes[0,3].set_title('node3')
disk_df4[['rkB/s', 'wkB/s']].plot(ax=axes[1,0]); axes[1,0].set_title('node4')
disk_df5[['rkB/s', 'wkB/s']].plot(ax=axes[1,1]); axes[1,1].set_title('node5')
disk_df6[['rkB/s', 'wkB/s']].plot(ax=axes[1,2]); axes[1,2].set_title('node6')
disk_df7[['rkB/s', 'wkB/s']].plot(ax=axes[1,3]); axes[1,3].set_title('node7')
# Out:
# Text(0.5, 1.0, 'node7')

# %%
mem_df0 = pd.read_csv(profile + '/' + nodes[0] + '/sar_mem.sar', skiprows=2, sep='\s+')
mem_df1 = pd.read_csv(profile + '/' + nodes[1] + '/sar_mem.sar', skiprows=2, sep='\s+')
mem_df2 = pd.read_csv(profile + '/' + nodes[2] + '/sar_mem.sar', skiprows=2, sep='\s+')
mem_df3 = pd.read_csv(profile + '/' + nodes[3] + '/sar_mem.sar', skiprows=2, sep='\s+')
mem_df4 = pd.read_csv(profile + '/' + nodes[4] + '/sar_mem.sar', skiprows=2, sep='\s+')
mem_df5 = pd.read_csv(profile + '/' + nodes[5] + '/sar_mem.sar', skiprows=2, sep='\s+')
mem_df6 = pd.read_csv(profile + '/' + nodes[6] + '/sar_mem.sar', skiprows=2, sep='\s+')
mem_df7 = pd.read_csv(profile + '/' + nodes[7] + '/sar_mem.sar', skiprows=2, sep='\s+')

# %%
fig, axes = plt.subplots(nrows=2, ncols=4)
mem_df0['%memused'].plot(ax=axes[0,0]); axes[0,0].set_title('node0')
mem_df1['%memused'].plot(ax=axes[0,1]); axes[0,1].set_title('node1')
mem_df2['%memused'].plot(ax=axes[0,2]); axes[0,2].set_title('node2')
mem_df3['%memused'].plot(ax=axes[0,3]); axes[0,3].set_title('node3')
mem_df4['%memused'].plot(ax=axes[1,0]); axes[1,0].set_title('node4')
mem_df5['%memused'].plot(ax=axes[1,1]); axes[1,1].set_title('node5')
mem_df6['%memused'].plot(ax=axes[1,2]); axes[1,2].set_title('node6')
mem_df7['%memused'].plot(ax=axes[1,3]); axes[1,3].set_title('node7')
# Out:
# Text(0.5, 1.0, 'node7')

# %%
nic_df0 = pd.read_csv(profile + '/' + nodes[0] + '/sar_nic.sar', skiprows=2, sep='\s+', index_col='IFACE')
nic_df0 = nic_df0.loc['enp125s0']
nic_df1 = pd.read_csv(profile + '/' + nodes[1] + '/sar_nic.sar', skiprows=2, sep='\s+', index_col='IFACE')
nic_df1 = nic_df1.loc['enp125s0']
nic_df2 = pd.read_csv(profile + '/' + nodes[2] + '/sar_nic.sar', skiprows=2, sep='\s+', index_col='IFACE')
nic_df2 = nic_df2.loc['enp125s0']
nic_df3 = pd.read_csv(profile + '/' + nodes[3] + '/sar_nic.sar', skiprows=2, sep='\s+', index_col='IFACE')
nic_df3 = nic_df3.loc['enp125s0']
nic_df4 = pd.read_csv(profile + '/' + nodes[4] + '/sar_nic.sar', skiprows=2, sep='\s+', index_col='IFACE')
nic_df4 = nic_df4.loc['enp125s0']
nic_df5 = pd.read_csv(profile + '/' + nodes[5] + '/sar_nic.sar', skiprows=2, sep='\s+', index_col='IFACE')
nic_df5 = nic_df5.loc['enp125s0']
nic_df6 = pd.read_csv(profile + '/' + nodes[6] + '/sar_nic.sar', skiprows=2, sep='\s+', index_col='IFACE')
nic_df6 = nic_df6.loc['enp125s0']
nic_df7 = pd.read_csv(profile + '/' + nodes[7] + '/sar_nic.sar', skiprows=2, sep='\s+', index_col='IFACE')
nic_df7 = nic_df7.loc['enp125s0']

# %%
fig, axes = plt.subplots(nrows=2, ncols=4)
nic_df0[['rxkB/s', 'txkB/s']].plot(ax=axes[0,0]); axes[0,0].set_title('node0')
nic_df1[['rxkB/s', 'txkB/s']].plot(ax=axes[0,1]); axes[0,1].set_title('node1')
nic_df2[['rxkB/s', 'txkB/s']].plot(ax=axes[0,2]); axes[0,2].set_title('node2')
nic_df3[['rxkB/s', 'txkB/s']].plot(ax=axes[0,3]); axes[0,3].set_title('node3')
nic_df4[['rxkB/s', 'txkB/s']].plot(ax=axes[1,0]); axes[1,0].set_title('node4')
nic_df5[['rxkB/s', 'txkB/s']].plot(ax=axes[1,1]); axes[1,1].set_title('node5')
nic_df6[['rxkB/s', 'txkB/s']].plot(ax=axes[1,2]); axes[1,2].set_title('node6')
nic_df7[['rxkB/s', 'txkB/s']].plot(ax=axes[1,3]); axes[1,3].set_title('node7')
# Out:
# Text(0.5, 1.0, 'node7')
